# %%
import numpy as np, pandas as pd, seaborn as sns, sklearn, matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.gridspec as gridspec

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig,ax = plt.subplots(3,3,figsize = (20,20))
g = gridspec.GridSpec(3, 3)
# violin plot
a = plt.subplot(g[0,:])
#sns.violinplot(data = df, ax = a, orient = 'h')
#sns.violinplot(df['petal_length'],ax = a)
sns.violinplot(df['sepal_width'],ax = a, orient = 'h')
a.set_title('Violin Plot')


# histogram plot
b = plt.subplot(g[1,0])
#sns.histplot(df['petal_length'],ax = b, kde = True)
#sns.histplot(data = df, x = 'petal_width', y = 'petal_width',ax = b)
sns.histplot(df['sepal_width'],ax = b, kde = True)
b.set_title('histogram')

# mean, median, mode
c = plt.subplot(g[1,1])
#sns.kdeplot(data = df, x = 'petal_width', y = 'sepal_width',ax = c )
sns.kdeplot(df['petal_width'],  ax = c)
median = df['petal_width'].median()
mean = df['petal_width'].mean()
std_dev = df['petal_width'].std()
for i in range(1, 4):
    plt.axvline(median + i*std_dev, color='gray')
    plt.axvline(median - i*std_dev, color='blue')
    plt.axvline(mean+i*std_dev, color = 'black')
    plt.axvline(mean - i*std_dev,color = 'green')
c.set_title('Density')


# scatter plot

d = plt.subplot(g[1,2])
sns.scatterplot(data = df, x = 'petal_width', y = 'sepal_width', hue = 'species', ax = d)
d.set_title('scatterplot')


#pie chart
e = plt.subplot(g[2,0])
df['species'].value_counts().plot.pie(autopct='%1.1f%%', explode=[0.1, 0, 0], ax=e)
e.set_title('piechart')

#countplot
f = plt.subplot(g[2,1])
#sns.countplot(data = df, x = 'species', ax = f)
sns.countplot(data = df, y = 'petal_length', ax = f)
f.set_title('countplot')

#swarnplot
g = plt.subplot(g[2,2])
sns.swarmplot(data = df, x = 'petal_width', y = 'sepal_width',hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_width'>

# %%
sns.catplot(data = df, x = 'petal_width', y = 'sepal_width', hue = 'species', kind = 'strip', col ='species' )

# %%
df1 = pd.read_csv(r"C:\Users\Boggu\Downloads\Titanic_s_1.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df2 = df1.drop(columns = 'Cabin')

# %%
df2.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
fig,ax = plt.subplots(3,3,figsize = (20,20))
g = gridspec.GridSpec(3, 3)



# violin plot
a = plt.subplot(g[0,0])
sns.violinplot(df2['Age'], ax = a, orient = 'h')

a.set_title('violin_plot')


#sccatterplot
b = plt.subplot(g[0,1])
sns.scatterplot(df2['Fare'], ax = b)
b.set_title('scatterplot')


#countplot

c = plt.subplot(g[0,2])
sns.countplot(data = df2, x = 'Fare')
c.set_title('count_plot')


#boxenplot

d = plt.subplot(g[1,0])
sns.boxenplot(data = df2, y = 'Age', x = 'Embarked', hue = 'Survived')
d.set_title('boxen_plot')



#kdeplot


e = plt.subplot(g[1,1])
sns.kdeplot(df2['Age'],ax = e)
e.set_title('kdeplot')


#barplot

f = plt.subplot(g[1,2])
sns.barplot(df2['Survived'], ax = f)


# catplot
g = plt.subplot(g[2,:])
sns.catplot(data = df2, x = 'Embarked', y = 'Survived', hue = 'Pclass', kind = 'violin', col = 'Pclass')
